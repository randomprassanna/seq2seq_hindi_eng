# %%
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import spacy
import torch
import torch.nn as nn
import torch.optim as optim
import torchtext
from torch.utils.tensorboard import SummaryWriter

# %%
df = pd.read_csv('/home/prassanna/M/DL/TEXT/seq2seq/dataset/hindi_english_parallel.csv')

# %%
small_data = df.iloc[:1000,:]

# %%
small_data.to_csv('small_data.csv')

# %%
small = pd.read_csv('/home/prassanna/M/DL/TEXT/seq2seq/small_data.csv')
small
# Out:
#      Unnamed: 0                                              hindi  \
# 0             0    अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# 1             1                    एक्सेर्साइसर पहुंचनीयता अन्वेषक
# 2             2              निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# 3             3               ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# 4             4  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से नि...
# ..          ...                                                ...
# 995         995                                       एक्सेर्साइसर
# 996         996    अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# 997         997                    एक्सेर्साइसर पहुंचनीयता अन्वेषक
# 998         998  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से नि...
# 999         999  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से नि...
#
#                                              english
# 0     Give your application an accessibility workout
# 1                  Accerciser Accessibility Explorer
# 2     The default plugin layout for the bottom panel
# 3        The default plugin layout for the top panel
# 4     A list of plugins that are disabled by default
# ..                                               ...
# 995                                       Accerciser
# 996   Give your application an accessibility workout
# 997                Accerciser Accessibility Explorer
# 998   A list of plugins that are disabled by default
# 999  A list of plugins that are disabled by default.
#
# [1000 rows x 3 columns]

# %%
# train_test_split(X, y, test_size=0.3, shuffle=True)
# train = small_data.sample(frac=0.7)

# %%
train, testtemp = train_test_split(small_data, test_size=0.3, shuffle=True)

# %%
val , test = train_test_split(testtemp, test_size=0.5, shuffle=True)

# %% [markdown]
# #### now we have train,val, test

# %%
spacy_hi = spacy.load("xx_sent_ud_sm") #multilang model
spacy_en = spacy.load("en_core_web_sm") 

def tokenize_hi(text):
    return [tok.text for tok in spacy_hi.tokenizer(text)]


def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
dataset = train

# %%
from torchtext.vocab import vocab
from collections import Counter, OrderedDict

hindi = dataset.iloc[:,0].values
eng = dataset.iloc[:,1].values

tok_hindi =[(tokenize_hi(sent)) for sent in hindi]
tok_eng =[(tokenize_en(sent)) for sent in eng]


def get_counter(tok_data):
    counter = Counter()
    for i in range(len(tok_data)):
        counter.update(tok_data[i]) 
    return counter

def build_vocab(tok_data):
    counter = get_counter(tok_data)
    sorted_by_freq_tuples = sorted(counter.items(), key=lambda x: x[1], reverse=True) 
    #text as a key,index as a value
    ordered_dict = OrderedDict(sorted_by_freq_tuples)
    voc = vocab(ordered_dict, min_freq=1)
    return voc

# %%
def get_sent_indexarray(sent, voc_lang):
    arr = [voc_lang([word]) for word in sent]
    return arr, len(arr)

def get_seq_len(data):
    tok_data_l = [get_sent_indexarray(tokenize_hi(sent), voc_lang) for sent in data]
    seq_vec = [i[0] for i in tok_data_l]
    seq_len = torch.LongTensor([i[1] for i in tok_data_l])
    return seq_vec, seq_len

# %%
def pad_sequences(seq_vec, seq_len):
    seq_tensor = torch.zeros((len(seq_vec), seq_len.max())).long()
    for idx, (seq_vec, seq_len) in enumerate(zip(seq_vec, seq_len)):
        seq_tensor[idx,:seq_len] = torch.LongTensor(seq_vec).squeeze()
    return seq_tensor

def make_variables_lang(data):
    seq_vec, seq_len = get_seq_len(data)
    return pad_sequences(seq_vec, seq_len)

# %%
voc = build_vocab(tok_hindi)
voc.get_stoi()
# Out:
# {'मूल': 423,
#  'प्लगिन': 421,
#  'विभाजन': 420,
#  'मुख्य': 418,
#  'लेकिन': 417,
#  'H': 416,
#  'छिपाएँ': 414,
#  'बिना': 413,
#  'बच्चों': 412,
#  'संयोजन': 411,
#  'hotkey': 410,
#  'ऊँचाई': 409,
#  'Start': 407,
#  'विभाजित': 405,
#  '©': 403,
#  'तेज': 401,
#  'प्रारंभEnd': 399,
#  'संस्करण': 396,
#  'काम': 394,
#  'गणना': 388,
#  'बाल': 387,
#  'कोशिकाlt;/bgt': 386,
#  'क्षैतिज': 419,
#  'दें': 385,
#  'व्यायाम': 383,
#  'त्रुटियां': 381,
#  'निगम': 380,
#  'आईबीएम': 379,
#  '2006,2007': 378,
#  'ओफसेट': 373,
#  'अंतः': 372,
#  'सारांशः': 371,
#  'पूरा': 370,
#  'संशोधनीय': 406,
#  '>': 369,
#  '<': 367,
#  'विशिष्ट': 366,
#  'खो': 363,
#  'वर्तमान': 361,
#  'कर': 360,
#  'निचले': 357,
#  'खाती': 356,
#  'A': 354,
#  'विचरक': 353,
#  'अनुप्रयोगः': 346,
#  'साथ%': 345,
#  'उसके': 344,
#  'मिटाने': 342,
#  'करनेयोग्य': 340,
#  'pluginviews': 338,
#  'खाली': 334,
#  'इसे': 331,
#  'आप': 330,
#  'क्या': 329,
#  'होगा': 328,
#  'आपको': 327,
#  'लाभ': 384,
#  'समाधान': 326,
#  'पाया': 324,
#  'दिखाएं': 335,
#  'देख': 323,
#  'मौजूद': 322,
#  'तो': 319,
#  'वह': 318,
#  'सकती': 317,
#  'bgt': 315,
#  'lt': 314,
#  '&': 313,
#  'दर्शक': 312,
#  'प्रबंधित': 308,
#  'पाइथन': 306,
#  'यूआरआई': 305,
#  'M': 303,
#  'घटनाओं': 302,
#  'निजी': 298,
#  'has': 293,
#  'हैbutton': 292,
#  'योग्य%': 291,
#  'प्रविष्ट': 289,
#  'छिपाएं': 299,
#  'मदद': 288,
#  'त्रुटि': 287,
#  'pluginview': 286,
#  'कुंजियां': 284,
#  'सहेज': 290,
#  'o': 281,
#  'चिह्नित': 278,
#  'शिफ्ट': 276,
#  'नीचे': 304,
#  'अवधिः': 275,
#  'शीर्षक': 274,
#  '?': 333,
#  'चौड़ाई': 273,
#  'ऊंचाई': 280,
#  'रोको': 272,
#  'आएंगे': 269,
#  'बाद': 267,
#  'सर्वाधिकार': 377,
#  'लोगआउट': 266,
#  'सत्रांत': 265,
#  'परिवर्तन': 264,
#  'श्वानपुच्छ': 262,
#  'फाइल': 259,
#  'प्रवाहित': 339,
#  'T': 285,
#  '@gmail': 257,
#  'हाइपरपाठ': 125,
#  'सहायक': 162,
#  'हाइलाइटन': 241,
#  'लेने': 395,
#  'करना': 123,
#  'फाइलें': 160,
#  'S': 310,
#  'किए': 103,
#  'में%': 179,
#  'एसपीआई': 176,
#  'विधियां': 223,
#  'चाहते': 332,
#  'से': 16,
#  'करता': 99,
#  'rolename': 80,
#  'E': 117,
#  'सेमेल': 355,
#  'अभिभावक': 116,
#  'विभिन्न': 94,
#  'दिखाएँ': 415,
#  'न्यूनतम': 97,
#  'अंत': 375,
#  'रकें': 183,
#  'पाठ': 111,
#  'न': 121,
#  'सदस्य': 135,
#  'सारणी': 92,
#  'विंडो': 86,
#  '/': 190,
#  'समय': 62,
#  'सत्यापक': 177,
#  'आईपाइथन': 374,
#  'विस्तारः': 245,
#  'विषय': 137,
#  'करने': 112,
#  'प्रकारों': 192,
#  'सूचक': 398,
#  'जैसे': 85,
#  ';': 75,
#  'सत्यापन': 79,
#  'नाम': 51,
#  'कुंजी': 148,
#  'खाका': 78,
#  'शीर्ष': 359,
#  'आसंधि': 96,
#  'सूचना': 63,
#  'R': 301,
#  '@yahoo': 114,
#  'घटना': 34,
#  'एक्सेर्साइसर': 77,
#  'स्तर': 104,
#  'सीमांत': 35,
#  'अपने': 382,
#  'बीएसडी': 102,
#  'इस': 73,
#  'ऊपरी': 71,
#  'जिस': 316,
#  'अधीन': 151,
#  'नई': 336,
#  'लिपि': 169,
#  'तयशुदा': 358,
#  'अवधि': 69,
#  'C': 98,
#  'जिन्हें': 89,
#  'शीर्षकः': 70,
#  '-': 3,
#  'वृद्धि': 393,
#  'com': 67,
#  'हाइपरकड़ी': 261,
#  '.': 26,
#  'चुनते': 131,
#  'विषयवस्तु': 341,
#  'निष्क्रिय': 91,
#  'एक्सेसेबलों': 277,
#  'माउस': 150,
#  'गायब': 142,
#  'पसंद': 66,
#  'डिफोल्टों': 180,
#  'पंजी': 300,
#  'मानिटर': 64,
#  'डेस्कटोप': 61,
#  'जाएगी': 364,
#  'प्रभाव': 268,
#  'अंतिम': 118,
#  'पंक्ति': 59,
#  'राज्य': 424,
#  'शामिल': 139,
#  'शिशु': 60,
#  'हैं': 28,
#  'स्तंभ': 33,
#  'जीयूआई': 390,
#  'x': 108,
#  'एक्सेसेबल': 83,
#  'प्लगइन्स': 351,
#  'सार्वत्रिक': 282,
#  'स्थिति': 44,
#  'शुरू': 271,
#  'राजेश': 250,
#  'मेथड': 216,
#  'अनुप्रयोग': 25,
#  'पारदर्शिता': 178,
#  '।': 27,
#  'focused': 294,
#  'विधियों': 215,
#  ',': 17,
#  'उन': 87,
#  'पटल': 41,
#  'सूची%': 57,
#  'करो': 115,
#  'गए': 22,
#  'अंतराफलक': 39,
#  'हटाएं': 182,
#  'मान': 19,
#  'घटक': 82,
#  'अनुलंब': 404,
#  'dead': 368,
#  'बार': 279,
#  'एक्सेसेबेलों': 219,
#  'अधिकतम': 126,
#  'समस्या': 325,
#  'और': 23,
#  '%': 14,
#  'सूचनाlt;/bgt': 400,
#  'गई': 55,
#  'नहीं': 8,
#  'index': 189,
#  'num2': 238,
#  'गुणों': 109,
#  'लिए': 15,
#  'एक': 95,
#  '...': 18,
#  'स्थान': 110,
#  'है': 2,
#  'लिपियां': 348,
#  'पहुंचनीय': 68,
#  'के': 5,
#  'आईडी': 201,
#  'ताजा': 56,
#  'विडजेट': 107,
#  'कई': 222,
#  'रेकोर्डिंग': 270,
#  'गया': 37,
#  'num': 184,
#  'अज्ञात': 397,
#  'वतनी': 365,
#  'बालसुब्रमण्यम': 254,
#  'अन्वेषक': 307,
#  '0': 76,
#  'देता': 244,
#  '(': 0,
#  'स्क्रिप्ट': 362,
#  'दृश्य': 12,
#  'अपवाद': 242,
#  'संग्रह': 124,
#  'किसी': 133,
#  'रेकोर्डर': 408,
#  'निरपेक्ष': 208,
#  'विवरण': 42,
#  'का': 11,
#  'इन': 20,
#  '_': 7,
#  'उसे': 153,
#  'प्राप्त': 213,
#  'हाइलाइट': 10,
#  'संपादित': 49,
#  'नोड': 52,
#  'चिह्नों': 120,
#  'एक्सेरसाइसर': 320,
#  'रंग': 24,
#  'दोषमुक्त': 258,
#  's': 9,
#  'focusable': 296,
#  'सभी': 58,
#  'चिह्न': 72,
#  'कंट्रोल': 149,
#  'रूप': 90,
#  'की': 21,
#  'कोई': 29,
#  'सक्रिय': 122,
#  'चुनी': 54,
#  'स्रोत': 168,
#  'पुस्तक': 32,
#  'मेल': 81,
#  'मूलभूत': 389,
#  'कन्सोल': 297,
#  'भराई': 43,
#  'करें': 6,
#  'डिफोल्ट': 45,
#  'कार्रवाई': 47,
#  'रंगः': 101,
#  'सूची': 38,
#  'चयन': 309,
#  'पहुंचनीयता': 48,
#  'योग्य': 113,
#  'हो': 106,
#  'नया': 40,
#  'state': 119,
#  'चुनें': 224,
#  'में': 31,
#  'क्रियान्वित': 172,
#  'शैली': 347,
#  'बक्से': 53,
#  'स्कीमाः': 127,
#  'जाल': 128,
#  'चुने': 30,
#  'आसंधियों': 146,
#  'पथः': 154,
#  'देखें': 422,
#  'पर': 130,
#  'संपन्न': 209,
#  'आल्ट': 132,
#  'समुच्चय': 134,
#  'मौजूदा': 136,
#  'अल्फा': 138,
#  'प्रारंभ': 140,
#  'संबंध': 141,
#  'जोड़ें': 155,
#  'होती': 196,
#  'औजार': 143,
#  'बक्सा': 144,
#  'शिशुओं': 147,
#  'जो': 152,
#  'अन्योन्य': 181,
#  'एकल': 74,
#  'बोर्डर': 156,
#  'करेंmenu': 350,
#  'चुनने': 221,
#  'विधि': 228,
#  'परीक्षण': 391,
#  'लाइसेन्स': 157,
#  'देखिए': 158,
#  'फोकस': 50,
#  'पंक्तियां': 163,
#  'बंधन': 376,
#  'प्रतिलिपीकरण': 159,
#  'and': 187,
#  'प्रवेश': 161,
#  'एमडीआई': 203,
#  'F': 260,
#  'd': 46,
#  'चुनाव': 145,
#  'वर्णन': 164,
#  'प्रकार': 202,
#  'त्रुटियांviewport': 343,
#  'पैनल': 165,
#  ')': 1,
#  'V': 206,
#  'रहे': 166,
#  'rajeshkajha': 252,
#  'एक्सेसेबेल': 167,
#  'जांचें': 84,
#  'विशिष्टः': 170,
#  'गुणधर्म': 171,
#  'हुआ': 173,
#  'ही': 100,
#  'एटी': 175,
#  'को': 4,
#  'खातेparent': 185,
#  'रंजन': 251,
#  'लेआउट': 105,
#  'indexrow': 186,
#  'फटाफट': 283,
#  'चयनीय': 65,
#  'column': 188,
#  'निचला': 191,
#  'एपीआई': 352,
#  'स्रोतों': 193,
#  'जेड': 204,
#  'घटनाएं': 194,
#  'उन्हें': 197,
#  'घटित': 195,
#  'आपके': 321,
#  'भूमिका': 200,
#  'num1': 237,
#  'पथ': 311,
#  'टिप्पणीः': 263,
#  'क्रम': 205,
#  'without': 295,
#  'N': 207,
#  'बहुत': 210,
#  'मिटाओ': 236,
#  'अपारदर्शिता': 211,
#  'दर्शाता': 198,
#  'जिसे': 212,
#  'उसकी': 214,
#  'विचरण': 217,
#  'जिसमें': 218,
#  'तेजी': 220,
#  'y': 225,
#  'I': 227,
#  'छवि': 226,
#  'c': 402,
#  'कार्य': 229,
#  'आकार': 230,
#  'raviratlami': 249,
#  'अंतर्क्रियात्मक': 231,
#  'चेतावनी': 232,
#  'उपलब्ध': 337,
#  'प्लग': 13,
#  'श्रीवास्तव': 248,
#  'कोशिका': 392,
#  'l.': 255,
#  'प्रलेख': 233,
#  'निर्मित': 349,
#  'इनों': 88,
#  'या': 234,
#  'पुष्टि': 174,
#  'रोजनामचा': 235,
#  'स्थल': 129,
#  'खाते': 239,
#  'अधिक': 93,
#  'अंतर्क्रियात्मक%': 240,
#  'देखने': 243,
#  'P': 246,
#  'सापेक्ष': 199,
#  'किया': 36,
#  'रविशंकर': 247,
#  'ल': 253,
#  'balasubramaniam': 256}

# %%
voc.insert_token( '<bos>',1 ) #'<bos>', '<eos>','<unk>',<pad>

# %%
len(voc)
# Out:
# 427

# %%
voc.get_stoi()
# Out:
# {'मूल': 425,
#  'प्लगिन': 423,
#  'विभाजन': 422,
#  'मुख्य': 420,
#  'लेकिन': 419,
#  'H': 418,
#  'छिपाएँ': 416,
#  'बिना': 415,
#  'बच्चों': 414,
#  'संयोजन': 413,
#  'hotkey': 412,
#  'ऊँचाई': 411,
#  'Start': 409,
#  'विभाजित': 407,
#  '©': 405,
#  'तेज': 403,
#  'प्रारंभEnd': 401,
#  'संस्करण': 398,
#  'काम': 396,
#  'गणना': 390,
#  'बाल': 389,
#  'कोशिकाlt;/bgt': 388,
#  'क्षैतिज': 421,
#  'दें': 387,
#  'व्यायाम': 385,
#  'त्रुटियां': 383,
#  'निगम': 382,
#  'आईबीएम': 381,
#  '2006,2007': 380,
#  'ओफसेट': 375,
#  'अंतः': 374,
#  'सारांशः': 373,
#  'पूरा': 372,
#  'संशोधनीय': 408,
#  '>': 371,
#  '<': 369,
#  'विशिष्ट': 368,
#  'खो': 365,
#  'वर्तमान': 363,
#  'कर': 362,
#  'निचले': 359,
#  'खाती': 358,
#  'A': 356,
#  'विचरक': 355,
#  'अनुप्रयोगः': 348,
#  'साथ%': 347,
#  'उसके': 346,
#  'मिटाने': 344,
#  'करनेयोग्य': 342,
#  'pluginviews': 340,
#  'खाली': 336,
#  'इसे': 333,
#  'आप': 332,
#  'क्या': 331,
#  'होगा': 330,
#  'आपको': 329,
#  'लाभ': 386,
#  'समाधान': 328,
#  'पाया': 326,
#  'दिखाएं': 337,
#  'देख': 325,
#  'मौजूद': 324,
#  'तो': 321,
#  'वह': 320,
#  'सकती': 319,
#  'bgt': 317,
#  'lt': 316,
#  '&': 315,
#  'दर्शक': 314,
#  'प्रबंधित': 310,
#  'पाइथन': 308,
#  'यूआरआई': 307,
#  'M': 305,
#  'घटनाओं': 304,
#  'निजी': 300,
#  'has': 295,
#  'हैbutton': 294,
#  'योग्य%': 293,
#  'प्रविष्ट': 291,
#  'छिपाएं': 301,
#  'मदद': 290,
#  'त्रुटि': 289,
#  'pluginview': 288,
#  'कुंजियां': 286,
#  'सहेज': 292,
#  'o': 283,
#  'चिह्नित': 280,
#  'शिफ्ट': 278,
#  'नीचे': 306,
#  'अवधिः': 277,
#  'शीर्षक': 276,
#  '?': 335,
#  'चौड़ाई': 275,
#  'ऊंचाई': 282,
#  'रोको': 274,
#  'आएंगे': 271,
#  'बाद': 269,
#  'सर्वाधिकार': 379,
#  'लोगआउट': 268,
#  'सत्रांत': 267,
#  'परिवर्तन': 266,
#  'श्वानपुच्छ': 264,
#  'फाइल': 261,
#  'प्रवाहित': 341,
#  'T': 287,
#  '@gmail': 259,
#  'balasubramaniam': 258,
#  'कोशिका': 394,
#  'l.': 257,
#  'लेने': 397,
#  'करना': 125,
#  'फाइलें': 162,
#  'S': 312,
#  'किए': 105,
#  'में%': 181,
#  'एसपीआई': 178,
#  'विधियां': 225,
#  'चाहते': 334,
#  'से': 18,
#  'करता': 101,
#  'rolename': 82,
#  'E': 119,
#  'सेमेल': 357,
#  'अभिभावक': 118,
#  'विभिन्न': 96,
#  'दिखाएँ': 417,
#  'न्यूनतम': 99,
#  'अंत': 377,
#  'रकें': 185,
#  'पाठ': 113,
#  'न': 123,
#  'सदस्य': 137,
#  'सारणी': 94,
#  'विंडो': 88,
#  '/': 192,
#  'समय': 64,
#  'सत्यापक': 179,
#  'आईपाइथन': 376,
#  'विस्तारः': 247,
#  'विषय': 139,
#  'करने': 114,
#  'प्रकारों': 194,
#  'सूचक': 400,
#  'जैसे': 87,
#  ';': 77,
#  'सत्यापन': 81,
#  'नाम': 53,
#  'कुंजी': 150,
#  'खाका': 80,
#  'शीर्ष': 361,
#  'आसंधि': 98,
#  'सूचना': 65,
#  'R': 303,
#  '@yahoo': 116,
#  'घटना': 36,
#  'एक्सेर्साइसर': 79,
#  'स्तर': 106,
#  'सीमांत': 37,
#  'अपने': 384,
#  'बीएसडी': 104,
#  'इस': 75,
#  'ऊपरी': 73,
#  'जिस': 318,
#  'अधीन': 153,
#  'नई': 338,
#  'लिपि': 171,
#  'तयशुदा': 360,
#  'अवधि': 71,
#  'C': 100,
#  'जिन्हें': 91,
#  'शीर्षकः': 72,
#  '-': 5,
#  'वृद्धि': 395,
#  'com': 69,
#  'हाइपरकड़ी': 263,
#  '.': 28,
#  'चुनते': 133,
#  'विषयवस्तु': 343,
#  'निष्क्रिय': 93,
#  'एक्सेसेबलों': 279,
#  'माउस': 152,
#  'गायब': 144,
#  'पसंद': 68,
#  'डिफोल्टों': 182,
#  'पंजी': 302,
#  'मानिटर': 66,
#  'डेस्कटोप': 63,
#  'जाएगी': 366,
#  'प्रभाव': 270,
#  'अंतिम': 120,
#  'पंक्ति': 61,
#  'सूची%': 59,
#  'करो': 117,
#  'जीयूआई': 392,
#  'x': 110,
#  'एक्सेसेबल': 85,
#  'प्लगइन्स': 353,
#  'सार्वत्रिक': 284,
#  'स्थिति': 46,
#  'शुरू': 273,
#  'राजेश': 252,
#  'मेथड': 218,
#  'अनुप्रयोग': 27,
#  ',': 19,
#  'उन': 89,
#  'पटल': 43,
#  'गए': 24,
#  'अंतराफलक': 41,
#  'हटाएं': 184,
#  'मान': 21,
#  'घटक': 84,
#  'अनुलंब': 406,
#  'dead': 370,
#  'बार': 281,
#  'एक्सेसेबेलों': 221,
#  'सूचनाlt;/bgt': 402,
#  'गई': 57,
#  'नहीं': 10,
#  'index': 191,
#  'num2': 240,
#  'पारदर्शिता': 180,
#  '।': 29,
#  'focused': 296,
#  'विधियों': 217,
#  'समस्या': 327,
#  '%': 16,
#  'और': 25,
#  'अधिकतम': 128,
#  'है': 4,
#  'स्क्रिप्ट': 364,
#  'दृश्य': 14,
#  'अपवाद': 244,
#  'अन्वेषक': 309,
#  '0': 78,
#  'देता': 246,
#  '(': 2,
#  'गुणों': 111,
#  'लिए': 17,
#  'एक': 97,
#  '...': 20,
#  'स्थान': 112,
#  'लिपियां': 350,
#  'पहुंचनीय': 70,
#  'के': 7,
#  'आईडी': 203,
#  'ताजा': 58,
#  'विडजेट': 109,
#  'कई': 224,
#  'रेकोर्डिंग': 272,
#  'गया': 39,
#  'num': 186,
#  'अज्ञात': 399,
#  'वतनी': 367,
#  'बालसुब्रमण्यम': 256,
#  'focusable': 298,
#  'सभी': 60,
#  'संग्रह': 126,
#  'किसी': 135,
#  'रेकोर्डर': 410,
#  'निरपेक्ष': 210,
#  'विवरण': 44,
#  'का': 13,
#  'इन': 22,
#  '_': 9,
#  'उसे': 155,
#  'प्राप्त': 215,
#  'हाइलाइट': 12,
#  'संपादित': 51,
#  'नोड': 54,
#  'चिह्नों': 122,
#  'एक्सेरसाइसर': 322,
#  'रंग': 26,
#  'दोषमुक्त': 260,
#  's': 11,
#  'राज्य': 426,
#  'शामिल': 141,
#  'शिशु': 62,
#  'हैं': 30,
#  'स्तंभ': 35,
#  'चिह्न': 74,
#  'कंट्रोल': 151,
#  'रूप': 92,
#  'की': 23,
#  'कोई': 31,
#  'सक्रिय': 124,
#  'चुनी': 56,
#  'स्रोत': 170,
#  'पुस्तक': 34,
#  'मेल': 83,
#  '<bos>': 1,
#  'मूलभूत': 391,
#  'कन्सोल': 299,
#  'भराई': 45,
#  'करें': 8,
#  'डिफोल्ट': 47,
#  'कार्रवाई': 49,
#  'रंगः': 103,
#  'सूची': 40,
#  'चयन': 311,
#  'पहुंचनीयता': 50,
#  'योग्य': 115,
#  'हो': 108,
#  'नया': 42,
#  'state': 121,
#  'चुनें': 226,
#  'में': 33,
#  'क्रियान्वित': 174,
#  'शैली': 349,
#  'बक्से': 55,
#  'हाइपरपाठ': 127,
#  'सहायक': 164,
#  'हाइलाइटन': 243,
#  'स्कीमाः': 129,
#  'जाल': 130,
#  'चुने': 32,
#  'आसंधियों': 148,
#  'पथः': 156,
#  'देखें': 424,
#  'पर': 132,
#  'संपन्न': 211,
#  'आल्ट': 134,
#  'समुच्चय': 136,
#  'मौजूदा': 138,
#  'अल्फा': 140,
#  'प्रारंभ': 142,
#  'संबंध': 143,
#  'जोड़ें': 157,
#  'होती': 198,
#  'औजार': 145,
#  'बक्सा': 146,
#  'शिशुओं': 149,
#  'जो': 154,
#  'अन्योन्य': 183,
#  'एकल': 76,
#  'बोर्डर': 158,
#  'करेंmenu': 352,
#  'चुनने': 223,
#  'विधि': 230,
#  'परीक्षण': 393,
#  'लाइसेन्स': 159,
#  'देखिए': 160,
#  'फोकस': 52,
#  'पंक्तियां': 165,
#  'बंधन': 378,
#  'प्रतिलिपीकरण': 161,
#  'and': 189,
#  'प्रवेश': 163,
#  'एमडीआई': 205,
#  'F': 262,
#  'd': 48,
#  'चुनाव': 147,
#  'वर्णन': 166,
#  'प्रकार': 204,
#  'त्रुटियांviewport': 345,
#  'पैनल': 167,
#  ')': 3,
#  'V': 208,
#  'रहे': 168,
#  'rajeshkajha': 254,
#  'एक्सेसेबेल': 169,
#  'जांचें': 86,
#  'विशिष्टः': 172,
#  'गुणधर्म': 173,
#  'हुआ': 175,
#  'ही': 102,
#  'एटी': 177,
#  'को': 6,
#  'खातेparent': 187,
#  'रंजन': 253,
#  'लेआउट': 107,
#  'indexrow': 188,
#  'फटाफट': 285,
#  'चयनीय': 67,
#  'column': 190,
#  'निचला': 193,
#  'एपीआई': 354,
#  'स्रोतों': 195,
#  'जेड': 206,
#  'घटनाएं': 196,
#  'उन्हें': 199,
#  'घटित': 197,
#  'आपके': 323,
#  'भूमिका': 202,
#  'num1': 239,
#  'पथ': 313,
#  'टिप्पणीः': 265,
#  'क्रम': 207,
#  'without': 297,
#  'N': 209,
#  'बहुत': 212,
#  'मिटाओ': 238,
#  '<pad>': 0,
#  'अपारदर्शिता': 213,
#  'दर्शाता': 200,
#  'जिसे': 214,
#  'उसकी': 216,
#  'विचरण': 219,
#  'जिसमें': 220,
#  'तेजी': 222,
#  'y': 227,
#  'I': 229,
#  'छवि': 228,
#  'c': 404,
#  'कार्य': 231,
#  'आकार': 232,
#  'raviratlami': 251,
#  'अंतर्क्रियात्मक': 233,
#  'चेतावनी': 234,
#  'उपलब्ध': 339,
#  'प्लग': 15,
#  'श्रीवास्तव': 250,
#  'प्रलेख': 235,
#  'निर्मित': 351,
#  'इनों': 90,
#  'या': 236,
#  'पुष्टि': 176,
#  'रोजनामचा': 237,
#  'स्थल': 131,
#  'खाते': 241,
#  'अधिक': 95,
#  'अंतर्क्रियात्मक%': 242,
#  'देखने': 245,
#  'P': 248,
#  'सापेक्ष': 201,
#  'किया': 38,
#  'रविशंकर': 249,
#  'ल': 255}

# %%
s,l = get_seq_len(hindi)

# %%
s[0]
# Out:
# [[78], [19], [78]]

# %%
from torchtext.vocab import Vocab
def full_vocab(tok_data):
    counter = get_counter(tok_data)
    return Vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'])

# %%
vocabulary = full_vocab(tok_hindi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [92], in <module>
# ----> 1 vocabulary = full_vocab(tok_hindi)
#
# Input In [91], in full_vocab(tok_data)
#       2 def full_vocab(tok_data):
#       3     counter = get_counter(tok_data)
# ----> 4     return Vocab(counter, specials=['<unk>', '<pad>', '<bos>', '<eos>'])
#
# TypeError: __init__() got an unexpected keyword argument 'specials'

# %%
len(vocabulary)
# Out:
# 116

# %%
vocabulary.get_stoi()
# Out:
# {'।': 115,
#  'V': 111,
#  'T': 110,
#  'P': 108,
#  'N': 107,
#  'M': 106,
#  'F': 103,
#  'A': 101,
#  '?': 100,
#  '>': 99,
#  '<': 98,
#  '7': 97,
#  '-': 94,
#  ')': 93,
#  '&': 91,
#  'ृ': 90,
#  'k': 87,
#  'f': 85,
#  'E': 83,
#  'H': 104,
#  '@': 82,
#  '1': 95,
#  ',': 81,
#  'ऊ': 78,
#  '/': 72,
#  'ओ': 70,
#  'v': 69,
#  'p': 68,
#  'w': 66,
#  'c': 65,
#  'x': 75,
#  '.': 63,
#  '%': 60,
#  'श': 26,
#  'R': 109,
#  'ज': 23,
#  'ञ': 114,
#  'I': 105,
#  'च': 21,
#  'म': 20,
#  'त': 14,
#  'प': 13,
#  'स': 9,
#  'ु': 24,
#  'ँ': 77,
#  'फ': 52,
#  'द': 28,
#  'इ': 36,
#  'b': 58,
#  'र': 6,
#  'S': 84,
#  ';': 74,
#  'ट': 22,
#  'क': 8,
#  '<bos>': 2,
#  '6': 96,
#  'ठ': 89,
#  'ै': 59,
#  'ो': 16,
#  '<eos>': 3,
#  '(': 92,
#  '0': 64,
#  '्': 5,
#  '_': 112,
#  'औ': 88,
#  'ः': 51,
#  'य': 15,
#  'ा': 4,
#  'ौ': 80,
#  '़': 79,
#  '2': 73,
#  'ध': 34,
#  '<unk>': 0,
#  'C': 102,
#  'घ': 67,
#  'ि': 7,
#  'छ': 71,
#  'न': 10,
#  'व': 19,
#  'ष': 40,
#  'े': 12,
#  'ए': 27,
#  'ं': 11,
#  'ह': 25,
#  'थ': 55,
#  '©': 113,
#  'ग': 29,
#  'a': 32,
#  'e': 41,
#  'ब': 30,
#  'अ': 31,
#  'ल': 17,
#  'आ': 33,
#  'r': 53,
#  't': 35,
#  '<pad>': 1,
#  'ई': 37,
#  'ड': 38,
#  'ू': 39,
#  'u': 48,
#  'n': 42,
#  'g': 61,
#  'ख': 43,
#  'y': 76,
#  'भ': 44,
#  'o': 45,
#  'i': 46,
#  'l': 47,
#  'm': 50,
#  'उ': 54,
#  'ण': 49,
#  'd': 56,
#  'j': 86,
#  'h': 62,
#  'ी': 18,
#  's': 57}

# %%
vocabulary['<eos>']
# Out:
# 3

# %%
voc.insert_token('<eos>','<unk>',2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <module>
# ----> 1 voc.insert_token('<eos>','<unk>',2,3)
#
# TypeError: insert_token() takes 3 positional arguments but 5 were given

# %%
voc.insert_token('<eos>', 2)

# %% [markdown]
# ### we can add bos eos unk  etc by concatenation inside seq-len function

# %%
BOS_IDX = voc['<bos>']
EOS_IDX = voc['<eos>']

# %%
s[0]
# Out:
# [[78], [19], [78]]

# %%
new_s0 = torch.cat([torch.tensor([BOS_IDX]), torch.tensor(s[0]), torch.tensor([EOS_IDX])], dim=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [100], in <module>
# ----> 1 new_s0 = torch.cat([torch.tensor([BOS_IDX]), torch.tensor(s[0]), torch.tensor([EOS_IDX])], dim=0)
#
# RuntimeError: Tensors must have same number of dimensions: got 1 and 2

# %%
new_s0 = torch.cat([torch.tensor([[BOS_IDX]]), torch.tensor(s[0]), torch.tensor([[EOS_IDX]])], dim=0)

# %%
new_s0
# Out:
# tensor([[ 1],
#         [78],
#         [19],
#         [78],
#         [ 2]])

# %%
new_s0.squeeze() #while padding required
# Out:
# tensor([ 1, 78, 19, 78,  2])

# %%
def mydataset(eng, hindi):
    train_dataset = []
    list_eng_tensors = make_variables_lang(eng)
    list_hi_tensors = make_variables_lang(hindi)
    for (eng_tensors, hi_tensors) in zip(list_eng_tensors, list_hi_tensors):
        data.append((eng_tensor, hi_tensor))
    return train_dataset

# %% [markdown]
#  ### but here out my variable function creates whole tensor of entire dat. we want tuples of single input tensors of eng hin (see nect notebook)

# %%
# def mycollate(data_batch):
#     eng_batch, hi_batch = [], []
#     for (de_item, en_item) in data_batch:
        
#     return de_batch, en_batch

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_dataset, batch_size, shuffle=True, num_workers =8, pin_memory=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [111], in <module>
#       1 from torch.utils.data import DataLoader
# ----> 2 train_dl = DataLoader(train_dataset, batch_size, shuffle=True, num_workers =8, pin_memory=True)
#
# NameError: name 'train_dataset' is not defined

# %%
ds = mydataset(eng, hindi)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [112], in <module>
# ----> 1 ds = mydataset(eng, hindi)
#
# Input In [107], in mydataset(eng, hindi)
#       1 def mydataset(eng, hindi):
#       2     model_dataset = []
# ----> 3     list_eng_tensors = make_variables_lang(eng)
#       4     list_hi_tensors = make_variables_lang(hindi)
#       5     for (eng_tensors, hi_tensors) in zip(list_eng_tensors, list_hi_tensors):
#
# Input In [55], in make_variables_lang(data)
#       7 def make_variables_lang(data):
# ----> 8     seq_vec, seq_len = get_seq_len(data)
#       9     return pad_sequences(seq_vec, seq_len)
#
# Input In [54], in get_seq_len(data)
#       5 def get_seq_len(data):
# ----> 6     tok_data_l = [get_sent_indexarray(tokenize_hi(sent)) for sent in data]
#       7     seq_vec = [i[0] for i in tok_data_l]
#       8     seq_len = torch.LongTensor([i[1] for i in tok_data_l])
#
# Input In [54], in <listcomp>(.0)
#       5 def get_seq_len(data):
# ----> 6     tok_data_l = [get_sent_indexarray(tokenize_hi(sent)) for sent in data]
#       7     seq_vec = [i[0] for i in tok_data_l]
#       8     seq_len = torch.LongTensor([i[1] for i in tok_data_l])
#
# Input In [54], in get_sent_indexarray(sent)
#       1 def get_sent_indexarray(sent):
# ----> 2     arr = [voc([word]) for word in sent]
#       3     return arr, len(arr)
#
# Input In [54], in <listcomp>(.0)
#       1 def get_sent_indexarray(sent):
# ----> 2     arr = [voc([word]) for word in sent]
#       3     return arr, len(arr)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torchtext/vocab/vocab.py:34, in Vocab.forward(self, tokens)
#      24 @torch.jit.export
#      25 def forward(self, tokens: List[str]) -> List[int]:
#      26     r"""Calls the `lookup_indices` method
#      27
#      28     Args:
#    (...)
#      32         The indices associated with a list of `tokens`.
#      33     """
# ---> 34     return self.vocab.lookup_indices(tokens)
#
# RuntimeError: Token Preferences not found and default index is not set

# %% [markdown]
# #### we have yet to make eng vocab

# %%
arrrr = get_sent_indexarray(tokenize_hi('हाइलाइट किया गया भराई का रंग और पारदर्शिता।'))

# %%
arrrr
# Out:
# ([[10], [36], [37], [43], [11], [24], [23], [178], [27]], 9)

# %%
z = make_variables_lang(hindi)

# %%
voc['होगा']
# Out:
# 328
